# %%
f <- read.csv("rii_srz_0.02.csv")
f2 <- read.csv("rii_srz_0.04.csv")
f3 <- read.csv("rii_srz_0.06.csv")
f4 <- read.csv("rii_srz_0.08.csv")
da <- cbind("instance"=f$Instance,"0.02"=round(f$Percentage.deviation,2),"0.04"=round(f2$Percentage.deviation,2),"0.06"=round(f3$Percentage.deviation,2),"0.08"=round(f4$Percentage.deviation,2))

#da[,-1] <-round(da[,-1],0)
da
# Out:
#       instance  0.02 0.04 0.06 0.08
#  [1,] 100_20_01 1.96 2.24 2.07 2.42
#  [2,] 100_20_02 1.85 1.92 2.51 2.87
#  [3,] 100_20_03 2.62 2.24 2.81 2.77
#  [4,] 100_20_04 2.29 2.64 2.85 3.16
#  [5,] 100_20_05 2.75 3.44 2.91 3.82
#  [6,] 100_20_06 2.59 2.52 3.29 2.82
#  [7,] 100_20_07 2.44 2.16 3.09 3.4
#  [8,] 100_20_08 2.2  2.32 3.03 3.68
#  [9,] 100_20_09 2.06 2.21 2.75 3.96
# [10,] 100_20_10 2.56 3.31 2.68 3.5
# [11,] 100_20_11 2.79 3.47 2.84 3.21
# [12,] 100_20_12 1.09 1.1  2.01 2.15
# [13,] 100_20_13 2.59 2.6  2.98 3.09
# [14,] 100_20_14 2.91 3.53 3.65 3.98
# [15,] 100_20_15 2.64 3.22 3.6  3.68
# [16,] 100_20_16 2.28 3.18 3.09 3.5
# [17,] 100_20_17 2.86 2.96 3.35 2.85
# [18,] 100_20_18 2.14 2.31 3.49 3.39
# [19,] 100_20_19 3.26 3.24 3.13 3.84
# [20,] 100_20_20 2.36 2.52 2.86 3.04
# [21,] 100_20_21 2.1  2.52 3.87 3.44
# [22,] 100_20_22 2.28 3.12 3.16 3.49
# [23,] 100_20_23 2.77 3.36 3.35 3.74
# [24,] 100_20_24 3.11 2.65 3.76 3.82
# [25,] 100_20_25 2.63 2.55 3.33 3.54
# ...

# %%
merge(f,f2,f3,f4,f5)
# Out:
# Error in fix.by(by.x, x): 'by' must specify one or more columns as numbers, names or logical
# Traceback:
#
# 1. merge(f, f2, f3, f4, f5, by = 0)
# 2. merge.data.frame(f, f2, f3, f4, f5, by = 0)
# 3. fix.by(by.x, x)
# 4. stop("'by' must specify one or more columns as numbers, names or logical")
