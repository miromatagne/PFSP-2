# %%
f <- read.csv("ils_lambda_30_gamma_2.csv")
f2 <- read.csv("ils_lambda_30_gamma_4.csv")
f3 <- read.csv("ils_lambda_30_gamma_8.csv")
f4 <- read.csv("ils_lambda_30_gamma_10.csv")
da <- cbind("instance"=f$Instance,"2"=round(f$Percentage.deviation,2),"4"=round(f2$Percentage.deviation,2),"8"=round(f3$Percentage.deviation,2),"10"=round(f4$Percentage.deviation,2))

#da[,-1] <-round(da[,-1],0)
da
# Out:
#       instance  2    4    8    10
#  [1,] 100_20_01 1.57 1.57 1.54 1.71
#  [2,] 100_20_02 1.65 1.62 1.62 1.48
#  [3,] 100_20_03 0.65 0.77 0.81 0.73
#  [4,] 100_20_04 1.97 1.86 1.83 2.17
#  [5,] 100_20_05 2.25 2.13 2.22 1.78
#  [6,] 100_20_06 1.98 2.3  2.26 2.06
#  [7,] 100_20_07 1.63 1.63 1.26 1.39
#  [8,] 100_20_08 1.93 1.99 1.93 2.08
#  [9,] 100_20_09 0.73 0.68 0.77 0.72
# [10,] 100_20_10 1.99 2.04 1.84 1.64
# [11,] 100_20_11 2.38 2.38 2.38 2.38
# [12,] 100_20_12 0.99 1.01 0.8  0.62
# [13,] 100_20_13 2.27 2.07 2.24 2.16
# [14,] 100_20_14 1.8  1.61 1.78 1.71
# [15,] 100_20_15 2.56 2.22 2.18 2.45
# [16,] 100_20_16 2.14 2.19 2.28 2.18
# [17,] 100_20_17 1.4  1.31 1.34 1.33
# [18,] 100_20_18 1.08 1.11 1.17 1.16
# [19,] 100_20_19 2.17 2.17 2.17 2.17
# [20,] 100_20_20 1.58 1.43 1.68 1.55
# [21,] 100_20_21 2.29 2.28 2.21 2.11
# [22,] 100_20_22 1.65 1.71 1.41 1.7
# [23,] 100_20_23 2.3  2.64 2.46 2.92
# [24,] 100_20_24 1.88 1.93 2.4  2.1
# [25,] 100_20_25 1.9  2.05 1.88 2.15
# ...

# %%
f <- read.csv("./wilcoxon_test_data")
da <- cbind("instance"=f$Instance,"RII Percentage Deviation"=round(f$RII.Percentage.deviation,2),"ILS Percentage Deviation"=round(f$ILS.Percentage.Deviation,2))

da
# Out:
#       instance   RII Percentage Deviation ILS Percentage Deviation
#  [1,] 100_20_01  1.96                     1.51
#  [2,] 100_20_02  1.85                     1.45
#  [3,] 100_20_03  2.62                     0.79
#  [4,] 100_20_04  2.29                     1.75
#  [5,] 100_20_05  2.75                     2.08
#  [6,] 100_20_06  2.59                     2.32
#  [7,] 100_20_07  2.44                     1.48
#  [8,] 100_20_08  2.2                      2
#  [9,] 100_20_09  2.06                     0.77
# [10,] 100_20_10  2.56                     1.72
# [11,] 100_20_11  2.79                     2.38
# [12,] 100_20_12  1.09                     0.98
# [13,] 100_20_13  2.59                     2.27
# [14,] 100_20_14  2.91                     1.64
# [15,] 100_20_15  2.64                     2.21
# [16,] 100_20_16  2.28                     1.96
# [17,] 100_20_17  2.86                     1.66
# [18,] 100_20_18  2.14                     1.14
# [19,] 100_20_19  3.26                     2.17
# ...

# %%
merge(f,f2,f3,f4,f5)
# Out:
# Error in fix.by(by.x, x): 'by' must specify one or more columns as numbers, names or logical
# Traceback:
#
# 1. merge(f, f2, f3, f4, f5, by = 0)
# 2. merge.data.frame(f, f2, f3, f4, f5, by = 0)
# 3. fix.by(by.x, x)
# 4. stop("'by' must specify one or more columns as numbers, names or logical")
