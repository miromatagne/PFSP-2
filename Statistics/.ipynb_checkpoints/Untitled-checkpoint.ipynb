# %%
f <- read.csv("rii_random_0.1.csv")
f2 <- read.csv("rii_random_0.1.csv")
f3 <- read.csv("rii_random_0.1.csv")
f4 <- read.csv("rii_random_0.1.csv")
f5 <- read.csv("rii_random_0.1.csv")

# %%
merge(f,f1,f2,f3,f4,f5)
# Out:
#    Instance  Percentage.deviation
# 1  100_20_01 25.708299
# 2  100_20_02 23.660709
# 3  100_20_03 30.101591
# 4  100_20_04 25.171918
# 5  100_20_05 27.078559
# 6  100_20_06 30.632641
# 7  100_20_07 28.431929
# 8  100_20_08 29.753692
# 9  100_20_09 19.775303
# 10 100_20_10 24.182402
# 11 100_20_11 25.878379
# 12 100_20_12 27.264136
# 13 100_20_13 26.020469
# 14 100_20_14 29.675069
# 15 100_20_15 29.581158
# 16 100_20_16 24.903070
# 17 100_20_17 27.851624
# 18 100_20_18 30.699930
# 19 100_20_19 27.512780
# 20 100_20_20 26.189236
# 21 100_20_21 24.807527
# 22 100_20_22 23.918141
# 23 100_20_23 26.424406
# 24 100_20_24 29.145178
# 25 100_20_25 27.463846
# 26 100_20_26 27.724660
# 27 100_20_27 25.627605
# 28 100_20_28 31.169717
# 29 100_20_29 24.521888
# 30 100_20_30 26.885684
# 31 50_20_01   9.894869
# 32 50_20_02  10.371628
# 33 50_20_03  12.528187
# 34 50_20_04  11.086629
# 35 50_20_05  11.685910
# 36 50_20_06   9.352644
# 37 50_20_07  10.006668
# 38 50_20_08  10.641067
# ...
